# %%
import pandas as pd

# %%
import pandas as pd

football = pd.read_csv('data/data_sf.csv', index_col=[0])
# display(football.head())
football.head()
# Out:
#                 Name  Age Nationality                 Club      Value    Wage  \
# 0           L. Messi   31   Argentina         FC Barcelona  110500000  565000
# 1  Cristiano Ronaldo   33    Portugal             Juventus   77000000  405000
# 2          Neymar Jr   26      Brazil  Paris Saint-Germain  118500000  290000
# 3             De Gea   27       Spain    Manchester United   72000000  260000
# 4       K. De Bruyne   27     Belgium      Manchester City  102000000  355000
#
#   Position  Crossing  Finishing  HeadingAccuracy  ...  Penalties  Composure  \
# 0       RF        84         95               70  ...         75         96
# 1       ST        84         94               89  ...         85         95
# 2       LW        79         87               62  ...         81         94
# 3       GK        17         13               21  ...         40         68
# 4      RCM        93         82               55  ...         79         88
#
# ...

# %%
football.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Club', 'Value', 'Wage', 'Position',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %%
grouped_df = football.groupby(['Club']).sum()
grouped_df
# Out:
#                        Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg   609  15195000   90000      1104        944
# 1. FC Heidenheim 1846  473  18290000   76000       961        860
# 1. FC Kaiserslautern   544  11195000   33000      1106        918
# 1. FC Köln             225  46810000   92000       444        357
# 1. FC Magdeburg        515  57525000   84000       948        903
# ...                    ...       ...     ...       ...        ...
# Zagłębie Sosnowiec     656   6815000   27000      1161       1007
# Çaykur Rizespor        557  27515000  118000      1110        921
# Örebro SK              622   8465000   36000      1114        974
# Östersunds FK          478  11030000   39000       944        805
# Śląsk Wrocław          628   9170000   50000      1058       1054
#
#                        HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# Club
#  SSV Jahn Regensburg              1283          1362      944       1196
# ...

# %%
# Out:
#                 Age         Value           Wage      Crossing     Finishing  \
# count  12897.000000  1.289700e+04   12897.000000  12897.000000  12897.000000
# mean      24.795379  2.112449e+06    7517.562224     47.076374     42.876328
# std        4.872212  6.498424e+06   23061.985387     18.043470     19.096935
# min       16.000000  0.000000e+00    1000.000000      5.000000      2.000000
# 25%       21.000000  2.500000e+05    1000.000000     35.000000     28.000000
# 50%       24.000000  5.000000e+05    2000.000000     51.000000     45.000000
# 75%       28.000000  8.500000e+05    4000.000000     61.000000     59.000000
# max       45.000000  1.185000e+08  565000.000000     93.000000     95.000000
#
#        HeadingAccuracy  ShortPassing       Volleys     Dribbling  \
# count     12897.000000  12897.000000  12897.000000  12897.000000
# mean         50.202528     56.026983     40.295030     52.461735
# std          17.281593     14.740436     17.080687     18.871643
# ...

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
grouped_df = football.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.head(5))
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
# Name: Wage, dtype: int64

# %%
grouped_df = football.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
grouped_df[grouped_df > 5000000]
# grouped_df
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# Name: Wage, dtype: int64

# %%
grouped_df = football.groupby(['Position'])[['Wage', 'Value']].mean().sort_values(['Value'],ascending=False)
grouped_df.head(5)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06

# %%
grouped_df = football.groupby(['Club'])['Wage'].agg(['mean', 'median'])[lambda a: a['mean'] == a['median']]
grouped_df
# Out:
#                            mean  median
# Club
# 1. FC Magdeburg          4000.0    4000
# AEK Athens               1000.0    1000
# AJ Auxerre               2000.0    2000
# Benevento                2000.0    2000
# Bohemian FC              1000.0    1000
# Boyacá Chicó FC          1000.0    1000
# Bray Wanderers           1000.0    1000
# Brøndby IF               6000.0    6000
# CD Feirense              4000.0    4000
# CD Tondela               2000.0    2000
# Cork City                1000.0    1000
# Cruzeiro                13000.0   13000
# Deportivo Pasto          1000.0    1000
# Dinamo Zagreb            1000.0    1000
# Dundalk                  1000.0    1000
# Dynamo Kyiv              1000.0    1000
# Envigado FC              1000.0    1000
# FC Energie Cottbus       1000.0    1000
# FC Metz                  1500.0    1500
# Grimsby Town             2000.0    2000
# Göztepe SK               7000.0    7000
# HJK Helsinki             1000.0    1000
# ...

# %%
grouped_df = football.groupby(['Club'])['Wage'].agg(['mean', 'median'])[lambda a: a['mean'] == a['median']]['mean']
grouped_df.max(),grouped_df.idxmax()
# Out:
# (13000.0, 'Cruzeiro')

# %%
grouped_df = football.groupby(['Club'])['Wage'].agg(['sum']) #[lambda a: a['mean'] == a['median']]['mean']
grouped_df
# Out:
#                           sum
# Club
#  SSV Jahn Regensburg    90000
# 1. FC Heidenheim 1846   76000
# 1. FC Kaiserslautern    33000
# 1. FC Köln              92000
# 1. FC Magdeburg         84000
# ...                       ...
# Zagłębie Sosnowiec      27000
# Çaykur Rizespor        118000
# Örebro SK               36000
# Östersunds FK           39000
# Śląsk Wrocław           50000
#
# [650 rows x 1 columns]

# %%
grouped_df.loc['Chelsea']
# Out:
# sum    2035000
# Name: Chelsea, dtype: int64

# %%
grouped_df[lambda a: a > 5000000]
# Out:
#                        sum
# Club
#  SSV Jahn Regensburg   NaN
# 1. FC Heidenheim 1846  NaN
# 1. FC Kaiserslautern   NaN
# 1. FC Köln             NaN
# 1. FC Magdeburg        NaN
# ...                    ...
# Zagłębie Sosnowiec     NaN
# Çaykur Rizespor        NaN
# Örebro SK              NaN
# Östersunds FK          NaN
# Śląsk Wrocław          NaN
#
# [650 rows x 1 columns]

# %%
football[(football['Nationality'] == 'Argentina') & (football['Club'] == 'FC Barcelona')][['Strength','Balance']]
# Out:
#    Strength  Balance
# 0        59       95

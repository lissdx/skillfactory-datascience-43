# %%
import pandas as pd

# %%
movies = pd.read_csv('data/movies.csv')
ratings = pd.read_csv('data/ratings.csv')

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
len(ratings)
# Out:
# 100836

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
movies.describe()
# Out:
#              movieId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000

# %%
items_dict = {

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 

    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],

    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]

}
purchase_log = {

    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 

    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]

}
items_df = pd.DataFrame(items_dict)
purchase_df = pd.DataFrame(purchase_log)

# %%
purchase_df.merge(items_df,on='item_id', how='left')
# Out:
#    purchase_id  item_id  price   vendor  stock_count
# 0          101   417283  13900  Samsung         54.0
# 1          101   849734   5330       LG         33.0
# 2          101   132223  38200    Apple        122.0
# 3          112   573943  49990    Apple         18.0
# 4          121    19475   9890       LG        102.0
# 5          145  3294095  33000    Apple         43.0
# 6          145   382043  67500  Samsung         77.0
# 7          145   302948  34500  Samsung        143.0
# 8          145   103845  89900      NaN          NaN
# 9          221   100132  11400       LG         60.0

# %%
purchase_df.merge(items_df,on='item_id', how='right')
# Out:
#    purchase_id  item_id    price   vendor  stock_count
# 0        101.0   417283  13900.0  Samsung           54
# 1        101.0   849734   5330.0       LG           33
# 2        101.0   132223  38200.0    Apple          122
# 3        112.0   573943  49990.0    Apple           18
# 4        121.0    19475   9890.0       LG          102
# 5        145.0  3294095  33000.0    Apple           43
# 6        145.0   382043  67500.0  Samsung           77
# 7        145.0   302948  34500.0  Samsung          143
# 8        221.0   100132  11400.0       LG           60
# 9          NaN   312394      NaN      ZTE           19

# %%
purchase_df.merge(items_df,on='item_id', how='inner')['item_id'].nunique()
# Out:
# 9

# %%
items_df.merge(purchase_df,on='item_id')[['stock_count','price']]
# Out:
#    stock_count  price
# 0           54  13900
# 1           33   5330
# 2          122  38200
# 3           18  49990
# 4          102   9890
# 5           43  33000
# 6           77  67500
# 7          143  34500
# 8           60  11400

# %%
items_df.merge(purchase_df,on='item_id')[['stock_count','price']].apply(lambda r: r['stock_count'] * r['price'], axis=1).sum()
# Out:
# 19729490

# %%
items_df=items_df.merge(purchase_df,on='item_id')[['stock_count','price']].apply(lambda r: r['stock_count'] * r['price'], axis=1)

# %%
items_df
# Out:
#    item_id   vendor  stock_count        ppp
# 0   417283  Samsung           54   750600.0
# 1   849734       LG           33   175890.0
# 2   132223    Apple          122  4660400.0
# 3   573943    Apple           18   899820.0
# 4    19475       LG          102  1008780.0
# 5  3294095    Apple           43  1419000.0
# 6   382043  Samsung           77  5197500.0
# 7   302948  Samsung          143  4933500.0
# 8   100132       LG           60   684000.0
# 9   312394      ZTE           19        NaN

# %%
import os

# %%
files = os.listdir('data_2/data')
files
# Out:
# ['ratings_8.txt',
#  'ratings_9.txt',
#  'ratings_10.txt',
#  'ratings_7.txt',
#  'ratings_6.txt',
#  'ratings_4.txt',
#  'ratings_5.txt',
#  'ratings_1.txt',
#  'ratings_2.txt',
#  'ratings_3.txt']

# %%
# files = ['setup.py', 'ratings.txt', 'stock_stats.txt', 'movies.txt', 'run.sh', 'game_of_thrones.mov']
# files

# %%
df_list = [pd.read_csv(f'data_2/data/{i}', header=None) for i in files if i[-4:] == '.txt' ]

# %%
big_df = pd.concat(df_list)
big_df
# Out:
#         0      1    2           3
# 0     483   1573  2.0  1465387568
# 1     483   1580  3.0  1465387435
# 2     483   1676  4.0  1465387586
# 3     483   1682  3.0  1465387384
# 4     483   1732  5.0  1465387406
# ...   ...    ...  ...         ...
# 9995  213  72701  2.5  1462644086
# 9996  213  72737  3.0  1462636677
# 9997  213  72919  2.5  1462637308
# 9998  213  72998  5.0  1462636393
# 9999  213  73015  2.0  1462636831
#
# [100004 rows x 4 columns]

# %%
df_list
# Out:
# [      483  1573  2.0  1465387568
#  0     483  1580  3.0  1465387435
#  1     483  1676  4.0  1465387586
#  2     483  1682  3.0  1465387384
#  3     483  1732  5.0  1465387406
#  4     483  1884  4.0  1465387578
#  ...   ...   ...  ...         ...
#  9994  547  8465  2.5  1190590946
#  9995  547  8477  4.0  1189018966
#  9996  547  8487  2.5  1199392319
#  9997  547  8491  4.5  1094783748
#  9998  547  8492  4.5  1199576393
#
#  [9999 rows x 4 columns],
#        547  8499  1.5  1087766595
#  0     547  8507  4.0  1434029572
#  1     547  8522  2.5  1136441189
#  2     547  8525  1.5  1199392371
#  3     547  8528  3.5  1432359375
#  4     547  8529  3.0  1119305825
#  ...   ...   ...  ...         ...
#  9994  597  2572  3.0   940707828
#  9995  597  2613  3.0   940707355
#  9996  597  2657  4.0   940707124
#  9997  597  2661  4.0   940707609
#  9998  597  2662  3.0   940707473
#
#  [9999 rows x 4 columns],
#         597  2664  5.0   940707473
#  0      597  2668  3.0   940707473
# ...

# %%
len(ratings[ratings['rating']==0.5])
# Out:
# 1370

# %%
len(ratings.merge(movies, on='movieId', how='outer'))
# Out:
# 100854

# %%
movies[movies['movieId']==3456]
# Out:
#       movieId                                         title genres
# 2587     3456  Color of Paradise, The (Rang-e khoda) (1999)  Drama
